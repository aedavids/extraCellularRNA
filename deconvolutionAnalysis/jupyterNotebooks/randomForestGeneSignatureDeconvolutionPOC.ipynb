# %% [markdown]
# # Random Forest Gene Signature Deconvolution POC
# Andrew E. Davidson
# aedavids@ucsc.edu
# 6/15/24
#
# Copyright (c) 2020-2023, Regents of the University of California All rights reserved. https://polyformproject.org/licenses/noncommercial/1.0.0
#
#
# # **Abstract**
# ## Deconvolution by Random forest output performs Deconvolution using non-negative matrix factorization methods like CIBERSORTx.
#
# We get better results, in a fraction of the time and memory required to run CIBERSORTx
#
# One of the hypotheses in my thesis proposal was that we could use transfer learning to create extracellular RNA classifiers. I.E. all RNA in plasma comes from cell. RNA features that work well in bulk tissue samples should work in our plasma samples however the distribution , i.e. model weight, will be different. The state-of-the-art bioinformatic deconvolution models use linear models. Linear models are easy to interrupt and match cell theory. You can think of the fraction vector produced by deconvolution methods the likelihood probabilities produced by multiclassification models. The input to CIBERSORTx is a signature matrix I constructed from our 1vsAll results and a “mixture matrix”. I.e. our bulk tissue samples. Each sample is one hot encoded.
#
# ## <span style="color:red"> TODO (things we could do)</span>
# * should we publish this?
# * create artificial mixtures and compare CIBERSORTx results against random forest
# * explore default Random Forest parameter and run hyper parameter tunning
#     * run cross validation in betwen 3 and 5 min
#     * create slurm script. only need 7GB of memory
#     * Create ROC and feature importance plots
#     * At the end of day we do not care about deconvolution, we want to build a plasma classifier. We should replace CIBERSORTx with random forest. It will save us days of compute time
#
# * <span style="color:red"> best10CuratedDegree1_ce467ff sorted base means in ascending order. We should use decending order. i.e. we want the largest base means. We could also set a min base mean threshold</span>
#
# ***
# ### **CIBERSORTx metric : specificit threshold: 0.96**
# | id |	mean_specificity |	median_specificity |	numGenes |	numTypes |	numDegree1 |	numAboveThreshold |	percentAboveThreshold |
# |----|-------------------|---------------------|-------------|-----------|-------------|----------------------|-----------------------|
# | best10CuratedDegree1_ce467ff	| 0.997855 |	0.999 |	716	| 83 |	83 |	83| 	1.000000 |
#
# ***
# ### **CIBERSORTx metric : sensitivity threshold: 0.9**
# | id | mean_sensitivity | median_sensitivity | numGenes | numTypes | numDegree1 | numAboveThreshold | percentAboveThreshold |
# |----|------------------|--------------------|---------|----------|------------|-------------------|-----------------------|
# | best10CuratedDegree1_ce467ff | 0.808831 | 0.871 | 716 | 83 | 83 | 36 | 0.433735 |
#
# ***
# ### **Random Forest cross validation with RepeatedStratifiedKFold(n_splits=5, n_repeats=1) metrics**
#
# ```
# {'fit_time'             : array([92.2722652 , 92.95103574, 93.0426476 , 92.35688996, 91.33328009]),
#  'score_time'           : array([0.33276272, 0.34168339, 0.33658481, 0.33685994, 0.33188391]),
#  'test_accuracy'        : array([0.92186017, 0.91234177, 0.92816456, 0.91170886, 0.91170886]),
#  'test_specificityMacro': array([1., 1., 1., 1., 1.]),
#  'test_sensitivityMacro': array([0.86359356, 0.85243009, 0.87229244, 0.84847883, 0.85098657]),
#  'test_aucMacro'        : array([0.99507937, 0.99728697, 0.99776633, 0.99754294, 0.99734611])}
# ```

# %%
import ipynbname

# use display() to print an html version of a data frame
# useful if dataFrame output is not generated by last like of cell
from IPython.display import display

import matplotlib.pyplot as plt 
import numpy as np
import os
import pandas as pd
# display all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from sklearn.ensemble      import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics         import recall_score
from sklearn.metrics         import roc_auc_score
from sklearn.metrics         import make_scorer

import sys

import logging
# Out:
# /data/tmp/ipykernel_3639622/2872795536.py:10: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
meaningOfLife = 42
notebookName = ipynbname.name()

# %%
#loglevel = "INFO"
loglevel = "WARN"
# logFMT = "%(asctime)s %(levelname)s [thr:%(threadName)s %(name)s %(funcName)s() line:%(lineno)s] [%(message)s]"
logFMT = "%(asctime)s %(levelname)s %(name)s %(funcName)s() line:%(lineno)s] [%(message)s]"
logging.basicConfig(format=logFMT, level=loglevel)    
logger = logging.getLogger(notebookName)

# %%
# setting the python path allows us to run python scripts from using
# the CLI. 
PYTHONPATH = os.environ['PYTHONPATH']
print("ORIG_PYTHONPATH: {}\n".format(PYTHONPATH))

gitRepoRoot = !git rev-parse --show-toplevel
gitRepoRoot = gitRepoRoot[0]

#
# add deconvolutionAnalysis modules
#
deconvolutionModules = f'{gitRepoRoot}/deconvolutionAnalysis/python'
print("deconvolutionModules: {}\n".format(deconvolutionModules))

PYTHONPATH = PYTHONPATH + f':{deconvolutionModules}'
#print("PYTHONPATH: {}\n".format(PYTHONPATH))

sys.path.append( str(deconvolutionModules) )
#print("\nsys.path:\n{}\n".format(sys.path))

#
# add intraExtraRNA_POC modules
#
intraExtraRNA_POCModules = f'{gitRepoRoot}/intraExtraRNA_POC/python/src'
print("intraExtraRNA_POCModules: {}\n".format(intraExtraRNA_POCModules))

PYTHONPATH = PYTHONPATH + f':{intraExtraRNA_POCModules}'
#print("PYTHONPATH: {}\n".format(PYTHONPATH))

sys.path.append( str(intraExtraRNA_POCModules) )
#print("\nsys.path:\n{}\n".format(sys.path))
# Out:
# ORIG_PYTHONPATH: :/private/home/aedavids/extraCellularRNA/src
#
# deconvolutionModules: /private/home/aedavids/extraCellularRNA/deconvolutionAnalysis/python
#
# intraExtraRNA_POCModules: /private/home/aedavids/extraCellularRNA/intraExtraRNA_POC/python/src

# %%
# local imports
#debug multi class from models.randomForestHyperparmeterSearch import createScoringMetricsDict
from models.randomForestHyperparmeterSearch import evaluateModel

# %%
runName = "best10CuratedDegree1_ce467ff"
weird = "best10CuratedDegree1"
rootDir = "/private/groups/kimlab/aedavids/deconvolution/1vsAll-~gender_category"
runOutDir = f'{rootDir}/{runName}/training/{weird}.sh.out'
ciberSortInput = "GTEx_TCGA-design-tilda_gender_category-padj-0001-lfc-20-n-10/ciberSortInput"

# %% [markdown]
# ## Create expected values
# i.e. one hot encoding

# %%
expectedFractionsPath = f'{runOutDir}/{ciberSortInput}/expectedFractions.txt'
! ls $expectedFractionsPath
# Out:
# /private/groups/kimlab/aedavids/deconvolution/1vsAll-~gender_category/best10CuratedDegree1_ce467ff/training/best10CuratedDegree1.sh.out/GTEx_TCGA-design-tilda_gender_category-padj-0001-lfc-20-n-10/ciberSortInput/expectedFractions.txt

# %%
# %%time
expectedFractionsDF = pd.read_csv(expectedFractionsPath, sep="\t",  index_col="sample_id")
print(f'expectedFractionsDF.shape : {expectedFractionsDF.shape}')
expectedFractionsDF.iloc[0:5, 0:9]
# Out:
# expectedFractionsDF.shape : (15801, 88)
# CPU times: user 111 ms, sys: 44 ms, total: 155 ms
# Wall time: 154 ms
#                          participant_id                category  gender   age  \
# sample_id
# GTEX-1117F-0226-SM-5GZZ7     GTEX-1117F    Adipose_Subcutaneous  Female  66.0
# GTEX-1117F-0526-SM-5EGHJ     GTEX-1117F           Artery_Tibial  Female  66.0
# GTEX-1117F-0726-SM-5GIEN     GTEX-1117F  Heart_Atrial_Appendage  Female  66.0
# GTEX-1117F-2826-SM-5GZXL     GTEX-1117F   Breast_Mammary_Tissue  Female  66.0
# GTEX-1117F-3226-SM-5N9CT     GTEX-1117F            Brain_Cortex  Female  66.0
#
#                          dataSet  ACC  Adipose_Subcutaneous  \
# sample_id
# GTEX-1117F-0226-SM-5GZZ7    GTEx  0.0                   1.0
# GTEX-1117F-0526-SM-5EGHJ    GTEx  0.0                   0.0
# GTEX-1117F-0726-SM-5GIEN    GTEx  0.0                   0.0
# GTEX-1117F-2826-SM-5GZXL    GTEx  0.0                   0.0
# GTEX-1117F-3226-SM-5N9CT    GTEx  0.0                   0.0
#
# ...

# %%
YSeries = expectedFractionsDF.loc[:,'category']
YSeries[0:5]
# Out:
# sample_id
# GTEX-1117F-0226-SM-5GZZ7      Adipose_Subcutaneous
# GTEX-1117F-0526-SM-5EGHJ             Artery_Tibial
# GTEX-1117F-0726-SM-5GIEN    Heart_Atrial_Appendage
# GTEX-1117F-2826-SM-5GZXL     Breast_Mammary_Tissue
# GTEX-1117F-3226-SM-5N9CT              Brain_Cortex
# Name: category, dtype: object

# %%
labelEncoder = LabelEncoder()
labelEncoder.fit(YSeries)
labelList = list( labelEncoder.classes_ )
print(len(labelList) )
labelList[0:5]
# Out:
# 83
# ['ACC',
#  'Adipose_Subcutaneous',
#  'Adipose_Visceral_Omentum',
#  'Adrenal_Gland',
#  'Artery_Aorta']

# %% [markdown]
# ## Load normalize counts
# convert to Random forest counts

# %%
mixturePath = f'{runOutDir}/{ciberSortInput}/mixture.txt'
! ls $mixturePath
# Out:
# /private/groups/kimlab/aedavids/deconvolution/1vsAll-~gender_category/best10CuratedDegree1_ce467ff/training/best10CuratedDegree1.sh.out/GTEx_TCGA-design-tilda_gender_category-padj-0001-lfc-20-n-10/ciberSortInput/mixture.txt

# %%
# %%time
mixtureDF = pd.read_csv(mixturePath, sep="\t", index_col="sampleTitle")
print(f'mixtureDF.shape : {mixtureDF.shape}')
mixtureDF.iloc[0:5, 0:5]
# Out:
# mixtureDF.shape : (716, 15801)
# CPU times: user 3.78 s, sys: 184 ms, total: 3.97 s
# Wall time: 3.96 s
#              GTEX-1117F-0226-SM-5GZZ7  GTEX-1117F-0526-SM-5EGHJ  \
# sampleTitle
# (GGTG)n                     19.001808                 26.644422
# (GT)n                      833.601046                664.744176
# (TA)n                       29.741960                 14.346997
# (TCCAC)n                     0.000000                  1.366381
# (TCTATG)n                    0.000000                  0.000000
#
#              GTEX-1117F-0726-SM-5GIEN  GTEX-1117F-2826-SM-5GZXL  \
# sampleTitle
# (GGTG)n                     12.776613                 72.892107
# (GT)n                      401.398583                918.272979
# (TA)n                       13.841330                 25.135209
# (TCCAC)n                     0.000000                  0.837840
# (TCTATG)n                    0.000000                  0.000000
#
#              GTEX-1117F-3226-SM-5N9CT
# sampleTitle
# ...

# %%
XDF = mixtureDF.transpose()
print(f'XDF.shape : {XDF.shape}')
XDF.iloc[0:5, 0:5]
# Out:
# XDF.shape : (15801, 716)
# sampleTitle                 (GGTG)n       (GT)n      (TA)n  (TCCAC)n  \
# GTEX-1117F-0226-SM-5GZZ7  19.001808  833.601046  29.741960  0.000000
# GTEX-1117F-0526-SM-5EGHJ  26.644422  664.744176  14.346997  1.366381
# GTEX-1117F-0726-SM-5GIEN  12.776613  401.398583  13.841330  0.000000
# GTEX-1117F-2826-SM-5GZXL  72.892107  918.272979  25.135209  0.837840
# GTEX-1117F-3226-SM-5N9CT  26.525577  427.061784   5.968255  0.000000
#
# sampleTitle               (TCTATG)n
# GTEX-1117F-0226-SM-5GZZ7   0.000000
# GTEX-1117F-0526-SM-5EGHJ   0.000000
# GTEX-1117F-0726-SM-5GIEN   0.000000
# GTEX-1117F-2826-SM-5GZXL   0.000000
# GTEX-1117F-3226-SM-5N9CT   0.663139

# %%
# Add the category column to counts
labeledXDF = pd.merge(XDF, expectedFractionsDF.loc[:, ['category']], how='inner',left_index=True, right_index=True) # left_on="sampleTitle", right_on="sample_id"
print(labeledXDF.shape)
display(labeledXDF.iloc[0:5, -5:])
# Out:
# (15801, 717)
#                                ZNRF1       ZRANB1      ZSWIM4      ZYG11B  \
# GTEX-1117F-0226-SM-5GZZ7  712.154709  1738.252329  247.849667  785.683443
# GTEX-1117F-0526-SM-5EGHJ  651.763560  1028.201423  151.668250  678.407982
# GTEX-1117F-0726-SM-5GIEN  234.237900   421.628220   98.486390  466.346365
# GTEX-1117F-2826-SM-5GZXL  918.272979   967.705557  318.379317  811.029419
# GTEX-1117F-3226-SM-5N9CT  590.857220   759.294632   94.828937  578.257571
#
#                                         category
# GTEX-1117F-0226-SM-5GZZ7    Adipose_Subcutaneous
# GTEX-1117F-0526-SM-5EGHJ           Artery_Tibial
# GTEX-1117F-0726-SM-5GIEN  Heart_Atrial_Appendage
# GTEX-1117F-2826-SM-5GZXL   Breast_Mammary_Tissue
# GTEX-1117F-3226-SM-5N9CT            Brain_Cortex

# %% [markdown]
# ## Convert to random forest format

# %%
XNP = XDF.values
print(f'XNP.shape : {XNP.shape}')
print(type(XNP))
print(XNP[0:5, 0:5])
# Out:
# XNP.shape : (15801, 716)
# <class 'numpy.ndarray'>
# [[1.90018078e+01 8.33601046e+02 2.97419600e+01 0.00000000e+00
#   0.00000000e+00]
#  [2.66444223e+01 6.64744176e+02 1.43469966e+01 1.36638063e+00
#   0.00000000e+00]
#  [1.27766127e+01 4.01398583e+02 1.38413305e+01 0.00000000e+00
#   0.00000000e+00]
#  [7.28921069e+01 9.18272979e+02 2.51352093e+01 8.37840309e-01
#   0.00000000e+00]
#  [2.65255767e+01 4.27061784e+02 5.96825475e+00 0.00000000e+00
#   6.63139417e-01]]

# %%
yNP = labelEncoder.transform( labeledXDF.loc[:, 'category'] ) # .values
# yNP = labelEncoder.transform( ['Adipose_Subcutaneous', 'Artery_Tibial', 'Heart_Atrial_Appendage',
#                                'UVM', 'UVM', 'UVM'] )
print(f'yNP.shape : {yNP.shape}')
print(f'yNP[0:5, :] \n{yNP[0:5]}')
print(f'\nlabelEncoder.inverse_transform( yNP ) :\n {labelEncoder.inverse_transform( yNP )}')
# Out:
# yNP.shape : (15801,)
# yNP[0:5, :]
# [ 1  6 39 23 15]
#
# labelEncoder.inverse_transform( yNP ) :
#  ['Adipose_Subcutaneous' 'Artery_Tibial' 'Heart_Atrial_Appendage' ... 'UVM'
#  'UVM' 'UVM']

# %%
labeledXDF.loc[:, 'category'].values
# Out:
# array(['Adipose_Subcutaneous', 'Artery_Tibial', 'Heart_Atrial_Appendage',
#        ..., 'UVM', 'UVM', 'UVM'], dtype=object)

# %% [markdown]
# # Train random forest
# <span style="color:red"> do we want to tweak the ways averages are calculated in createScoringMetricsDict</span>

# %%
#debug does not work wiht mulit class ################################################################################
from sklearn.metrics import make_scorer, recall_score, confusion_matrix, roc_auc_score

def specificity_score(y_true, y_pred, average='macro'):
    cm = confusion_matrix(y_true, y_pred)
    tn = cm[0, 0]
    fp = cm[0, 1]
    specificity = tn / (tn + fp)
    return specificity


specificityMacro = make_scorer(specificity_score, average='macro')

# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html#sklearn.metrics.recall_score
sensitivityMacro = make_scorer(recall_score, average='macro')

#
# check what different averaging methods do for binary classifier
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
# `multi_class='ovr' (one-vs-rest).
# average {'macro', 'micro', 'weighted'}
# aucMacro = make_scorer(roc_auc_score, average='macro', multi_class='ovr')
# aucNone = make_scorer(roc_auc_score, average=None, multi_class='ovr')
# aucMicro = make_scorer(roc_auc_score, average='micro', multi_class='ovr')
# aucWeighted= make_scorer(roc_auc_score, average='weighted', multi_class='ovr')

def multi_class_roc_auc_score(y_true, y_pred, average="macro"):
    # Apply the roc_auc_score function to each class
    return roc_auc_score(y_true, y_pred, average=average, multi_class='ovr')


# aucMacro = make_scorer(multi_class_roc_auc_score, needs_proba=True, average='macro')
aucMacro = make_scorer(multi_class_roc_auc_score, response_method='predict_proba', average='macro')

def createScoringMetricsDict(logger : logging.Logger) -> dict:
    '''
    https://stackoverflow.com/a/64540588/4586180
    The specifity is the True Negative Rate which is the same as the True Positive Rate (Recall)
    but for the negative class
    # !!! this assume we have a binary classifier.

    recall == sensitivity == true positive rate
    
    '''
    logger.info("BEGIN")
    # specificity,  and auc assume binary classifier
    # specificity = make_scorer(recall_score, pos_label=0)
    # auc = make_scorer( roc_auc_score )

    scoringMetricsDict = {
        'accuracy' : 'accuracy', # TP
        # assumes binary 'sensitivity' : 'recall',
        # assumes binary 'specificity' : specificity,
        'specificityMacro' : specificityMacro,
        'sensitivityMacro' : sensitivityMacro,
        # assumes binary 'auc' : auc,
        'aucMacro' : aucMacro,
        # 'aucNone' : aucNone,
        # 'aucMicro' : aucMicro,
        
        

        #'f1' : 'f1'
    } 

    logger.info("END")
    return scoringMetricsDict

# %%
# %%time

scoringMetricsDict = createScoringMetricsDict(logger) 


# rfModel = RandomForestClassifier(random_state=meaningOfLife, **kwags)
rfModel = RandomForestClassifier(random_state=meaningOfLife, )

# evaluateModel calls
# RepeatedStratifiedKFold() and cross_validate()
scoresDict = evaluateModel(logger, rfModel, XNP, yNP, scoringMetricsDict)


print("")
display( rfModel )
# Out:
# RandomForestClassifier(random_state=42)
# CPU times: user 392 ms, sys: 2.1 s, total: 2.49 s
# Wall time: 1min 36s

# %%
scoresDict
# Out:
# {'fit_time': array([92.00910878, 92.17471337, 92.7263906 , 91.39205122, 91.11508131]),
#  'score_time': array([0.33628011, 0.32968044, 0.34374261, 0.33773041, 0.34597683]),
#  'test_accuracy': array([0.92186017, 0.91234177, 0.92816456, 0.91170886, 0.91170886]),
#  'test_specificityMacro': array([1., 1., 1., 1., 1.]),
#  'test_sensitivityMacro': array([0.86359356, 0.85243009, 0.87229244, 0.84847883, 0.85098657]),
#  'test_aucMacro': array([0.99507937, 0.99728697, 0.99776633, 0.99754294, 0.99734611])}
